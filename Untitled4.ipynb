# %%
import urllib.request
import re

# %%
keyname="短裙"
#quote防止中文乱码
key=urllib.request.quote(keyname)
headers=("User-Agent","Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36")
opener=urllib.request.build_opener()
opener.addheaders=[headers]
urllib.request.install_opener(opener)
for i in range(0,5):
    url="https://s.taobao.com/search?q="+key+"&js=1&stats_click=search_radio_all%3A1&initiative_id=staobaoz_20181010&ie=utf8&bcoffset=3&ntoffset=3&p4ppushleft=1%2C48&s="+str(44*i)
    data=urllib.request.urlopen(url).read().decode("utf-8","ignore")
    pat='pic_url":"//(.*?)"'
    imagelist=re.compile(pat).findall(data)
    print(imagelist)
#     for j in range(0,len(imagelist)):
#         thisimg=imagelist[j]
#         thisimgurl="http://"+thisimg
#         file="F:/淘宝图片抓取/"+str(i)+str(j)+".jpg"
#         urllib.request.urlretrieve(thisimgurl,filename=file)
# Out:
# ['https://ics.hutton.ac.uk', 'https://ics.hutton.ac.uk/', 'https://ics.hutton.ac.uk/research/', 'https://ics.hutton.ac.uk/software/', 'https://ics.hutton.ac.uk/software/desktop-applications/', 'https://ics.hutton.ac.uk/software/web/', 'https://ics.hutton.ac.uk/software/mobile-apps/', 'https://ics.hutton.ac.uk/software/galaxy-extensions/', 'https://ics.hutton.ac.uk/software/tools/', 'https://ics.hutton.ac.uk/blogs/', 'https://ics.hutton.ac.uk/category/ics/', 'https://ics.hutton.ac.uk/category/cropgeeks/', 'https://ics.hutton.ac.uk/category/news/', 'https://ics.hutton.ac.uk/staff/', 'https://ics.hutton.ac.uk/publications/', 'https://ics.hutton.ac.uk/events/', 'https://ics.hutton.ac.uk/events/working-together-for-better-outcomes/', 'https://ics.hutton.ac.uk/contact-us/', 'http://twitter.com/cardinalb', 'http://twitter.com/huttonics', 'http://twitter.com/search?q=%23cropgeeks', 'http://twitter.com/search?q=%23helium', 'https://t.co/TW4OrddPBy', 'http://twitter.com/HuttonICS/status/107225
# ...

# %%
import re
import requests  
import time
import os
 
def get_one_html(url):  # 获取一个页面的html页面并返回
    try:
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'}
        r = requests.get(url, headers=headers)
        if r.status_code == 200:
            r.encoding = r.apparent_encoding
            return r.text
    except Exception as er:
        print(er)
    
def get_pic_url(html):  # 用正则提取每一页的关键信息返回
    pic_urls = re.findall('"pic_url":"(.*?)"', html, re.S)
    img_url = []     # 创建空列表，装每一页的所有图片的链接
    print(img_url)
    for one_pic_url in pic_urls:
        img_url.append('http:'+one_pic_url)
    return img_url   # 返回图片的链接的列表
 
def write_to_file(page, img_urls):  # 写入文件（下载）
    i = page   # 利用页码，防止后面的写入会覆盖之前的
    n = 0
    for pic_url in img_urls:
        pic = requests.get(pic_url)
        with open('F:/淘宝图抓取/'+str(i)+str(n)+'.jpg', 'wb') as f:
            f.write(pic.content)
        print('---第{}页第{}张图下载成功---'.format(str(i), str(n)))
        n += 1
 
def main(keyword, page_num, url):
    html = get_one_html(url)   # 调用函数得到该页的hml
    img_urls = get_pic_url(html)  # 调用函数得到该页的所有图片的链接
    write_to_file(page, img_urls)   # 调用函数，写入即下载图片
        
if __name__ == '__main__':
    keyword = input('请输入关键词：')
    page_num = eval(input('请输入要爬取的页数：'))
    try:
        for page in range(0, page_num):
            url = 'http://s.taobao.com/search?q='+keyword+'&s='+str(page)
            main(keyword, page_num, url)
            if page % 2 == 0:
                time.sleep(10)   # 每爬取2页停留10秒
    except Exception as err:
        print(err)
# Out:
# 请输入关键词：短裙
# 请输入要爬取的页数：2
# []
# []

# %%
import requests
import re
 
#获取页面函数、
def getHTMLText(url):
	try:
		r=requests.get(url,timeout=30)
		r.raise_for_status()
		r.encoding=r.apparent_encoding
		return r.text
	except:
		print("")
#对获取页面进行解析
def parsePage(ilt,html):
	try:
		#在爬取下来的网页中进行查找价格
		plt=re.findall(r'\"view_price\"\:\"[\d\.]*\"',html)
		#在爬取下来的网页中查找物品
		tlt=re.findall(r'\"raw_title\"\:\".*?\"',html)
		for i in range(len(plt)):
			price=eval(plt[i].split(':')[1])
			title=eval(tlt[i].split(':')[1])
			ilt.append([price,title])
	except:
		print("")
#进行打印
def printGoodsList(ilt):
	tplt = "{:4}\t{:8}\t{:16}"
	print(tplt.format("序号", "价格", "商品名称"))
	count = 0
	for g in ilt:
		count = count + 1
		print(tplt.format(count, g[0], g[1]))
 
def main():
	goods='书包'
	depth=2
	start_url='https://s.taobao.com/search?q='+goods
	infoList=[]
	for i in range(depth):
		try:
			#str函数的作用是将其中的内容转换为字符串
			url=start_url+'&s='+str(44*i)
			html=getHTMLText(url)
			parsePage(infoList , html)
		except:
			continue
	printGoodsList(infoList)
 
main()
# Out:
# 序号  	价格      	商品名称

# %%
import urllib.request
import re
#quote防止中文乱码
headers=("User-Agent","Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36")
opener=urllib.request.build_opener()
opener.addheaders=[headers]
urllib.request.install_opener(opener)
for i in range(0,5):
    url="http://www.58pic.com/tupian/8168998-0-0-"+str(i)+".html"
    data=urllib.request.urlopen(url).read().decode("utf-8","ignore")
    pat='original="(.*?)!'
    imagelist=re.compile(pat).findall(data)
    for j in range(0,len(imagelist)):
        thisimg=imagelist[j]
        thisimgurl="http://"+thisimg
        file="F:/淘宝图片抓取/"+str(i)+str(j)+".jpg"
        urllib.request.urlretrieve(thisimgurl,filename=file)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# ...

# %%
# Out:
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# unknown url type: '<img class="lazyload" data-original="(.*?).jpg!.jpg'
# ...

# %%
#千图网爬取代码
import urllib.request
import re
import urllib.error
headers=("User-Agent","Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36")
opener=urllib.request.build_opener()
opener.addheaders=[headers]
urllib.request.install_opener(opener)
for i in range(1,10):
    pageurl="http://www.58pic.com/tupian/8168998-0-0-"+str(i)+".html"
    data=urllib.request.urlopen(pageurl).read().decode("utf-8","ignore")
    pat='data-original="(.*?)!'
    imglist=re.compile(pat).findall(data)
    print(imglist)
    for j in range(0,len(imglist)):
        try:
            thisimg=imglist[j] 
            file="F:/淘宝图片抓取/"+str(i)+str(j)+".jpg"
            urllib.request.urlretrieve(thisimg,filename=file)
            print("第"+str(i)+str(j))
        except urllib.error.URLError as e:
            if hasattr(e,"code"):
                print(e.code)
        except Exception as e:
            print(e)
# Out:
# ['http://pic.qiantucdn.com/58pic/32/51/68/05u58PIC89p7k0u6158PICHkD_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/51/55/auto_39K58PIC6v85r4fqcI7x1_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/52/24/77958PICe58PICzfieSwctrcR_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/51/54/auto_15e58PICy2vX0QTGJUx77_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/48/26/43V58PICxRtYx8J6m1xg9_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/52/49/63058PICYxfMYcdh5yC7f_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/51/55/auto_63e58PICSK1NY00p6f4z5_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/49/77/58358PICddndtkemW0xRi_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/27/81/49/08P58PICQ26_1024.jpg', 'http://pic.qiantucdn.com/58pic/32/51/54/auto_58PIC1a58PIC66aXwB293E9us_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/27/79/93/96v58PICEkh_1024.jpg', 'http://pic.qiantucdn.com/58pic/32/49/89/auto_53Q58PICDd3jv6fh8kbQg_PIC2018.jpg', 'http://pic.qiantucdn.com/58pic/32/48/05/auto_46358PICJv2MH1wW
# ...

# %%
import urllib.request
proxy=urllib.request.ProxyHandler({"http":代理端口IP})
opener=urllib.request.build_opener(proxy,urllib.request.HTTPHandler)
urllib.request.install_opener(opener)
data=urllib.request.urlopen(url).read().decode("UTF-8")
